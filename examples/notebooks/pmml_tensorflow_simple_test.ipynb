# %%
from pandas import DataFrame
from tensorflow.contrib.learn import DNNClassifier, DNNRegressor, LinearClassifier, LinearRegressor, RunConfig
from tensorflow.contrib.layers import one_hot_column, real_valued_column, sparse_column_with_keys
from tensorflow.contrib.layers.python.layers.feature_column import _OneHotColumn, _RealValuedColumn, _SparseColumnKeys
from tensorflow.contrib.learn.python.learn.utils.input_fn_utils import InputFnOps

import numpy
import os
import pandas
import shutil
import tempfile
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

# %%
estimator_conf = RunConfig(num_cores = 1, tf_random_seed = 42)

def load_csv(name):
    df = pandas.read_csv(name)
    df.reset_index()
    return df

def store_csv(df, name):
    df.to_csv(name, index = False)

def store_savedmodel(estimator, serving_input_fn, name):
    savemodel_dir = estimator.export_savedmodel(tempfile.mkdtemp(), serving_input_fn = serving_input_fn, as_text = True)
    savemodel_dir = savemodel_dir.decode("UTF-8")

    if(os.path.isdir("savedmodel/" + name)):
        shutil.rmtree("savedmodel/" + name)
    shutil.move(savemodel_dir, "savedmodel/" + name)

def _dnn_feature_columns(feature_columns):
    return list(map(lambda x: one_hot_column(x) if isinstance(x, _SparseColumnKeys) else x, feature_columns))

def _input_fn(df, cont_feature_columns, cat_feature_columns, label_column):
    cont_features = {column : tf.constant(df[column].values, dtype = tf.float64, shape = [df[column].size, 1]) for column in cont_feature_columns}
    cat_features = {column : tf.constant(df[column].values, dtype = tf.string, shape = [df[column].size, 1]) for column in cat_feature_columns}
    features = dict(list(cont_features.items()) + list(cat_features.items()))
    label = tf.constant(df[label_column].values, shape = [df[label_column].size, 1])
    return features, label

def _serving_input_fn(cont_feature_columns, cat_feature_columns):
    cont_feature_placeholders = {column : tf.placeholder(dtype = tf.float64, shape = [None, 1], name = column) for column in cont_feature_columns}
    cat_feature_placeholders = {column : tf.placeholder(dtype = tf.string, shape = [None, 1], name = column) for column in cat_feature_columns}
    feature_placeholders = dict(list(cont_feature_placeholders.items()) + list(cat_feature_placeholders.items()))
    features = {column : tensor for column, tensor in feature_placeholders.items()}
    label = None
    return InputFnOps(features, label, feature_placeholders)

# %%
data_path = "~/Codecookies/machine-learning-workspace/datasets/iris/iris.data"
iris_df = load_csv(data_path)
iris_df.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "Species"]
iris_df["Species"] = iris_df[["Species"]].replace("Iris-setosa", "0").replace("Iris-versicolor", "1").replace("Iris-virginica", "2").astype(int)
iris_cont_columns = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
iris_feature_columns = [real_valued_column(column, dtype = tf.float64) for column in iris_cont_columns]

# %%
iris_df.as_matrix().shape
# Out:
# (149, 5)

# %%
def iris_input_fn():
    return _input_fn(iris_df, iris_cont_columns, [], "Species")

def iris_serving_input_fn():
    return _serving_input_fn(iris_cont_columns, [])

def build_iris(classifier, max_steps, name, with_proba = True):
    classifier.fit(input_fn = iris_input_fn, max_steps = max_steps)

    species = DataFrame(classifier.predict(input_fn = iris_input_fn, as_iterable = False), columns = ["_target"])
#     if(with_proba):
#         species_proba = DataFrame(classifier.predict_proba(input_fn = iris_input_fn, as_iterable = False), columns = ["probability(0)", "probability(1)", "probability(2)"])
#         species = pandas.concat((species, species_proba), axis = 1)
#     store_csv(species, name + ".csv")

    store_savedmodel(classifier, iris_serving_input_fn, name)

build_iris(DNNClassifier(hidden_units = [4 * 3, 2 * 3], feature_columns = _dnn_feature_columns(iris_feature_columns), n_classes = 3, optimizer = tf.train.AdamOptimizer, config = estimator_conf), 100, "DNNClassificationIris")
build_iris(LinearClassifier(feature_columns = iris_feature_columns, n_classes = 3, optimizer = tf.train.AdamOptimizer, config = estimator_conf), 5000, "LinearClassificationIris")
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp8wH7bj
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1058d34d0>, '_model_dir': '/var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp8wH7bj', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': 42, '_save_summary_steps': 100, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_tf_config': intra_op_parallelism_threads: 1
# inter_op_parallelism_threads: 1
# gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_evaluation_master': '', '_master': ''}
# WARNING:tensorflow:From /Users/lgrcyanny/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:192: get_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_global_step
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp8wH7bj/model.ckpt.
# INFO:tensorflow:loss = 1.13754, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp8wH7bj/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.745328.
# WARNING:tensorflow:From <ipython-input-5-abed11e35153>:10: calling predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:From /Users/lgrcyanny/anaconda2/lib/python2.7/site-packages/tensorflow/python/util/deprecation.py:381: calling predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /Users/lgrcyanny/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:418: calling predict_classes (from tensorflow.contrib.learn.python.learn.estimators.dnn) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:From /Users/lgrcyanny/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:454: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Restoring parameters from /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp8wH7bj/model.ckpt-100
# INFO:tensorflow:Restoring parameters from /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp8wH7bj/model.ckpt-100
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp0EWmEA/temp-1514344546/saved_model.pbtxt
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp685fK6
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a161d78d0>, '_model_dir': '/var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp685fK6', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': 42, '_save_summary_steps': 100, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_tf_config': intra_op_parallelism_threads: 1
# inter_op_parallelism_threads: 1
# gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_evaluation_master': '', '_master': ''}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp685fK6/model.ckpt.
# INFO:tensorflow:loss = 1.09861, step = 1
# INFO:tensorflow:global_step/sec: 992.396
# INFO:tensorflow:loss = 0.901577, step = 101 (0.104 sec)
# INFO:tensorflow:global_step/sec: 964.982
# INFO:tensorflow:loss = 0.772665, step = 201 (0.102 sec)
# INFO:tensorflow:global_step/sec: 962.528
# INFO:tensorflow:loss = 0.682233, step = 301 (0.105 sec)
# INFO:tensorflow:global_step/sec: 920.912
# INFO:tensorflow:loss = 0.61541, step = 401 (0.108 sec)
# INFO:tensorflow:global_step/sec: 963.094
# INFO:tensorflow:loss = 0.563768, step = 501 (0.106 sec)
# INFO:tensorflow:global_step/sec: 697.326
# INFO:tensorflow:loss = 0.522308, step = 601 (0.143 sec)
# INFO:tensorflow:global_step/sec: 912.234
# INFO:tensorflow:loss = 0.487955, step = 701 (0.108 sec)
# INFO:tensorflow:global_step/sec: 900.844
# INFO:tensorflow:loss = 0.458747, step = 801 (0.113 sec)
# INFO:tensorflow:global_step/sec: 907.705
# INFO:tensorflow:loss = 0.433388, step = 901 (0.109 sec)
# INFO:tensorflow:global_step/sec: 941.876
# INFO:tensorflow:loss = 0.410991, step = 1001 (0.107 sec)
# INFO:tensorflow:global_step/sec: 935.174
# INFO:tensorflow:loss = 0.390932, step = 1101 (0.106 sec)
# INFO:tensorflow:global_step/sec: 1074.16
# INFO:tensorflow:loss = 0.37276, step = 1201 (0.094 sec)
# INFO:tensorflow:global_step/sec: 935.024
# INFO:tensorflow:loss = 0.356142, step = 1301 (0.106 sec)
# INFO:tensorflow:global_step/sec: 1073.43
# INFO:tensorflow:loss = 0.340829, step = 1401 (0.092 sec)
# INFO:tensorflow:global_step/sec: 768.316
# INFO:tensorflow:loss = 0.326629, step = 1501 (0.134 sec)
# INFO:tensorflow:global_step/sec: 857.06
# INFO:tensorflow:loss = 0.313395, step = 1601 (0.114 sec)
# INFO:tensorflow:global_step/sec: 920.987
# INFO:tensorflow:loss = 0.30101, step = 1701 (0.107 sec)
# INFO:tensorflow:global_step/sec: 899.735
# INFO:tensorflow:loss = 0.28938, step = 1801 (0.113 sec)
# INFO:tensorflow:global_step/sec: 846.546
# INFO:tensorflow:loss = 0.278429, step = 1901 (0.117 sec)
# INFO:tensorflow:global_step/sec: 1083.42
# INFO:tensorflow:loss = 0.268094, step = 2001 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1068.59
# INFO:tensorflow:loss = 0.258322, step = 2101 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1034.38
# INFO:tensorflow:loss = 0.249068, step = 2201 (0.096 sec)
# INFO:tensorflow:global_step/sec: 860.038
# INFO:tensorflow:loss = 0.240293, step = 2301 (0.116 sec)
# INFO:tensorflow:global_step/sec: 1084.82
# INFO:tensorflow:loss = 0.231964, step = 2401 (0.093 sec)
# INFO:tensorflow:global_step/sec: 803.265
# INFO:tensorflow:loss = 0.224049, step = 2501 (0.124 sec)
# INFO:tensorflow:global_step/sec: 1014.6
# INFO:tensorflow:loss = 0.216521, step = 2601 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1077.06
# INFO:tensorflow:loss = 0.209358, step = 2701 (0.094 sec)
# INFO:tensorflow:global_step/sec: 901.315
# INFO:tensorflow:loss = 0.202536, step = 2801 (0.110 sec)
# INFO:tensorflow:global_step/sec: 1044.65
# INFO:tensorflow:loss = 0.196035, step = 2901 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1085.8
# INFO:tensorflow:loss = 0.189836, step = 3001 (0.091 sec)
# INFO:tensorflow:global_step/sec: 1042.06
# INFO:tensorflow:loss = 0.183923, step = 3101 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1072.06
# INFO:tensorflow:loss = 0.178279, step = 3201 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1048.12
# INFO:tensorflow:loss = 0.172891, step = 3301 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1048.15
# INFO:tensorflow:loss = 0.167743, step = 3401 (0.096 sec)
# INFO:tensorflow:global_step/sec: 753.301
# INFO:tensorflow:loss = 0.162824, step = 3501 (0.133 sec)
# INFO:tensorflow:global_step/sec: 1111.33
# INFO:tensorflow:loss = 0.158122, step = 3601 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1113.84
# INFO:tensorflow:loss = 0.153625, step = 3701 (0.090 sec)
# INFO:tensorflow:global_step/sec: 1069.7
# INFO:tensorflow:loss = 0.149323, step = 3801 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1063.94
# INFO:tensorflow:loss = 0.145205, step = 3901 (0.094 sec)
# INFO:tensorflow:global_step/sec: 970.403
# INFO:tensorflow:loss = 0.141264, step = 4001 (0.104 sec)
# INFO:tensorflow:global_step/sec: 763.691
# INFO:tensorflow:loss = 0.13749, step = 4101 (0.130 sec)
# INFO:tensorflow:global_step/sec: 854.058
# INFO:tensorflow:loss = 0.133874, step = 4201 (0.117 sec)
# INFO:tensorflow:global_step/sec: 984.398
# INFO:tensorflow:loss = 0.13041, step = 4301 (0.102 sec)
# INFO:tensorflow:global_step/sec: 719.616
# INFO:tensorflow:loss = 0.12709, step = 4401 (0.139 sec)
# INFO:tensorflow:global_step/sec: 1125.53
# INFO:tensorflow:loss = 0.123908, step = 4501 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1140.81
# INFO:tensorflow:loss = 0.120856, step = 4601 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1170.28
# INFO:tensorflow:loss = 0.117928, step = 4701 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1158.09
# INFO:tensorflow:loss = 0.115119, step = 4801 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1177.12
# INFO:tensorflow:loss = 0.112424, step = 4901 (0.085 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp685fK6/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.109862.
# WARNING:tensorflow:From <ipython-input-5-abed11e35153>:10: calling predict (from tensorflow.contrib.learn.python.learn.estimators.linear) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# WARNING:tensorflow:From /Users/lgrcyanny/anaconda2/lib/python2.7/site-packages/tensorflow/python/util/deprecation.py:381: calling predict (from tensorflow.contrib.learn.python.learn.estimators.linear) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /Users/lgrcyanny/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/linear.py:528: calling predict_classes (from tensorflow.contrib.learn.python.learn.estimators.linear) with as_iterable=False is deprecated and will be removed after 2016-09-15.
# Instructions for updating:
# The default behavior of predict() is changing. The default value for
# as_iterable will change to True, and then the flag will be removed
# altogether. The behavior of this flag is described below.
# INFO:tensorflow:Restoring parameters from /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp685fK6/model.ckpt-5000
# INFO:tensorflow:Restoring parameters from /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmp685fK6/model.ckpt-5000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /var/folders/1_/4_crrbzx2llc_qzmrngr4vx00000gn/T/tmpMbmhRn/temp-1514344556/saved_model.pbtxt

# %%
# java -cp ../../jpmml-tensorflow/target/converter-executable-1.0-SNAPSHOT.jar org.jpmml.tensorflow.Main --tf-input ./pmml-models/tensorflow/savedmodel/LinearClassificationIris/ --pmml-output ./pmml-models/tensorflow/linear_classifier.pmml
